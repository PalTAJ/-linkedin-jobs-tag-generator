# %%
import re, nltk, spacy, gensim, os
from bs4 import BeautifulSoup
from nltk.tokenize import ToktokTokenizer
from nltk.stem import wordnet
from nltk.corpus import stopwords
from string import punctuation
import pandas as pd
import emoji
import re
from nltk import ngrams


from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer

# %%
top_tags = []

def list_directories(path):
    """list files and directories in a given path"""
    arr = os.listdir(path)
    return arr

# %%
from keybert import KeyBERT

kw_model = KeyBERT()

# %%
def get_keywords(df,column='job-title'):
    
    tags = []
    texts = df[column].values.tolist()
#     text = ' '.join(texts)
    text = texts[0]
    
    keywords = kw_model.extract_keywords(text, keyphrase_ngram_range=(3,3),use_mmr=True ,stop_words=None,top_n=10)
    print(keywords,'\n')
    return keywords

# %%
data_path = 'data2'
files = list_directories(data_path)

category = []
for i in files:
    t = ''.join(i.split('_')[:-2])
    category.append(t)

    
data = []

for cat, file in zip(category,files):
    
    df = pd.read_csv(f"{data_path}/{file}") 
    print(cat)
    keywords = get_keywords(df,column='description')
#     break
# Out:
# Advertising & Public Relations
# [('visual merchandising coordinator', 0.683), ('prada headquarters in', 0.4347), ('support the vp', 0.3989), ('team functions responsiblities', 0.3191), ('hq visual office', 0.512), ('monitor project timelines', 0.3261), ('schedule manage orders', 0.346), ('visual department support', 0.5874), ('americas folders on', 0.2435), ('logistics coordinate projects', 0.379)]
#
# Business Economics
# [('barclays corporate investment', 0.7003), ('base pay range', 0.383), ('linkedin member reported', 0.1548), ('salaries for equity', 0.4988), ('71 400 00', 0.2983), ('research analyst at', 0.1867), ('york city metropolitan', 0.1979), ('analyst at barclays', 0.6016), ('bank in new', 0.2528), ('reported salaries for', 0.3712)]
#
# Special Education
# ...
